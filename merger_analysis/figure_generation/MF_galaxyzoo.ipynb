# %%
# %load_ext autoreload
# %autoreload 2

# %%
import matplotlib.pyplot as plt
from ekfplot import plot as ek
import fg_galaxyzoo
# Out:
# /Users/kadofong/opt/miniconda3/envs/merian/lib/python3.10/site-packages/umap/__init__.py:9: ImportWarning: Tensorflow not installed; ParametricUMAP will be unavailable
#   warn(

# %%
config = fg_galaxyzoo.load_config('../configs/galaxyzoo.yaml')
logger = fg_galaxyzoo.setup_logging('INFO')

# %%
data = fg_galaxyzoo.load_data(config,logger)
# Out:
# 2025-11-04 15:06:33,925 - fg_galaxyzoo - INFO - ============================================================
# 2025-11-04 15:06:33,925 - fg_galaxyzoo - INFO - ============================================================
# 2025-11-04 15:06:33,925 - fg_galaxyzoo - INFO - ============================================================
# 2025-11-04 15:06:33,927 - fg_galaxyzoo - INFO - LOADING DATA
# 2025-11-04 15:06:33,927 - fg_galaxyzoo - INFO - LOADING DATA
# 2025-11-04 15:06:33,927 - fg_galaxyzoo - INFO - LOADING DATA
# 2025-11-04 15:06:33,928 - fg_galaxyzoo - INFO - ============================================================
# 2025-11-04 15:06:33,928 - fg_galaxyzoo - INFO - ============================================================
# 2025-11-04 15:06:33,928 - fg_galaxyzoo - INFO - ============================================================
# 2025-11-04 15:06:33,929 - fg_galaxyzoo - INFO - Input path: ../../local_data/pieridae_output/starlet/massive_galaxies
# ...

# %%
output_dir = fg_galaxyzoo.Path('./punchline_figures/')

# %%
ix = 4
ix - (ix//3)*3
# Out:
# 1

# %%
fg_galaxyzoo.make_figure_galaxyzoo(data,output_dir,logger)
# Out:
# /Users/kadofong/work/projects/merian/pieridae/merger_analysis/figure_generation/fg_galaxyzoo.py:499: DeprecationWarning: invalid escape sequence '\p'
#   espr.max(axis=1)[:5].mean() - espr.max(axis=1)[:5].std(),
# 2025-11-04 16:44:39,433 - fg_galaxyzoo - INFO - Generating Galaxy Zoo EoD analysis figure
# 2025-11-04 16:44:39,433 - fg_galaxyzoo - INFO - Generating Galaxy Zoo EoD analysis figure
# 2025-11-04 16:44:39,433 - fg_galaxyzoo - INFO - Generating Galaxy Zoo EoD analysis figure
# 2025-11-04 16:44:39,436 - fg_galaxyzoo - INFO - Computing bootstrap histograms...
# 2025-11-04 16:44:39,436 - fg_galaxyzoo - INFO - Computing bootstrap histograms...
# 2025-11-04 16:44:39,436 - fg_galaxyzoo - INFO - Computing bootstrap histograms...
# 2025-11-04 16:44:40,221 - fg_galaxyzoo - INFO - Creating figure...
# 2025-11-04 16:44:40,221 - fg_galaxyzoo - INFO - Creating figure...
# 2025-11-04 16:44:40,221 - fg_galaxyzoo - INFO - Creating figure...
# ...
