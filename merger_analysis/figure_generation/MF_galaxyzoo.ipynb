# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import matplotlib.pyplot as plt
from ekfplot import plot as ek
import fg_galaxyzoo

# %%
config = fg_galaxyzoo.load_config('../configs/galaxyzoo.yaml')
logger = fg_galaxyzoo.setup_logging('INFO')

# %%
data = fg_galaxyzoo.load_data(config,logger)
# Out:
# 2025-11-17 13:25:40,049 - fg_galaxyzoo - INFO - ============================================================
# 2025-11-17 13:25:40,049 - fg_galaxyzoo - INFO - ============================================================
# 2025-11-17 13:25:40,050 - fg_galaxyzoo - INFO - LOADING DATA
# 2025-11-17 13:25:40,050 - fg_galaxyzoo - INFO - LOADING DATA
# 2025-11-17 13:25:40,053 - fg_galaxyzoo - INFO - ============================================================
# 2025-11-17 13:25:40,053 - fg_galaxyzoo - INFO - ============================================================
# 2025-11-17 13:25:40,054 - fg_galaxyzoo - INFO - Input path: ../../local_data/pieridae_output/starlet/massive_galaxies
# 2025-11-17 13:25:40,054 - fg_galaxyzoo - INFO - Input path: ../../local_data/pieridae_output/starlet/massive_galaxies
# 2025-11-17 13:25:40,055 - fg_galaxyzoo - INFO - Output path: ../output/galaxy_zoo
# 2025-11-17 13:25:40,055 - fg_galaxyzoo - INFO - Output path: ../output/galaxy_zoo
# 2025-11-17 13:25:40,055 - fg_galaxyzoo - INFO - Loading image names...
# 2025-11-17 13:25:40,055 - fg_galaxyzoo - INFO - Loading image names...
# 2025-11-17 13:25:41,829 - fg_galaxyzoo - INFO - Found 3565 images
# 2025-11-17 13:25:41,829 - fg_galaxyzoo - INFO - Found 3565 images
# 2025-11-17 13:25:41,830 - fg_galaxyzoo - INFO - Loading embeddings...
# 2025-11-17 13:25:41,830 - fg_galaxyzoo - INFO - Loading embeddings...
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 data = fg_galaxyzoo.load_data(config,logger)
#
# File ~/work/projects/merian/pieridae/merger_analysis/figure_generation/fg_galaxyzoo.py:174, in load_data(config, logger)
#     172 embeddings_file = output_path / 'embeddings.npy'
#     173 if not embeddings_file.exists():
# --> 174     raise FileNotFoundError(f"Embeddings not found: {embeddings_file}")
#     176 embeddings = np.load(embeddings_file)
#     177 data['embeddings'] = embeddings
#
# FileNotFoundError: Embeddings not found: ../output/galaxy_zoo/embeddings.npy

# %%
output_dir = fg_galaxyzoo.Path('./punchline_figures/')

# %%
fg_galaxyzoo.make_figure_galaxyzoo(data,None,logger)
# Out:
# 2025-11-11 11:15:05,145 - fg_galaxyzoo - INFO - Generating Galaxy Zoo EoD analysis figure
# 2025-11-11 11:15:05,150 - fg_galaxyzoo - INFO - Computing bootstrap histograms...
# 2025-11-11 11:15:05,863 - fg_galaxyzoo - INFO - Creating figure...
# 2025-11-11 11:15:07,111 - fg_galaxyzoo - INFO - Loading example images...
# 0.41\\pm0.15
# /Users/kadofong/work/projects/merian/pieridae/merger_analysis/figure_generation/fg_galaxyzoo.py:616: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   logger.info(f"Saved: {output_file}")
